# %%
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'serif'

# %%
sophie_taeuber_arp = ['#09009B', '#CF0004']

# %%
fig = plt.figure(figsize=(4, 3), dpi=500)
t = np.arange(0, 1.2, 0.001)
y1 = np.sin(2 * np.pi * t)
y2 = np.sin(2 * np.pi * t + 2.0)
plt.plot(t, y1, color=sophie_taeuber_arp[0])
plt.plot(t, y2, color=sophie_taeuber_arp[1])
plt.xlim(0, 1)
plt.xlabel('Time')
plt.title('True Latent Signal')
fig.tight_layout()
plt.savefig('sine_signal.png')
plt.show()

# %%
print(t.shape)
# Out:
# (1200,)

# %%
from scipy.linalg import expm, logm

# %%
def create_symmetric_matrix(upper):
    mat = np.zeros((5, 5))
    mat[0, :] = upper[:5]
    mat[1, 1:] = upper[5:9]
    mat[2, 2:] = upper[9:12]
    mat[3, 3:] = upper[12:14]
    mat[4, 4] = upper[14]
    for i in range(1, 5):
        for j in range(i):
            mat[i, j] = mat[j, i]
    return mat

# %%
F = np.zeros((1200, 2))
F[:, 0] = y1
F[:, 1] = y2

# %%
B = np.random.normal(0, 0.5, [2, 15])

# %%
log_series = np.matmul(F, B)
print(log_series.shape)
# Out:
# (1200, 15)

# %%
for j in range(15):
    plt.plot(log_series[:1000, j])
plt.show()

# %%
cov_series = np.zeros((1200, 5, 5))
for i in range(1200):
    cov_series[i, :, :] = expm(create_symmetric_matrix(log_series[i, :]))

# %%
fig = plt.figure(figsize=(10, 2), dpi=500)
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(cov_series[i * 200, :, :], cmap='coolwarm')
    plt.xticks([])
    plt.yticks([])
    plt.colorbar(fraction=0.046, pad=0.04)
#fig.tight_layout()
#plt.savefig('sine_cov.png')
plt.show()

# %%
time_series = np.zeros((1200, 5))
for i in range(1200):
    time_series[i, :] = np.random.multivariate_normal(np.zeros(5), cov_series[i, :, :], 1)

# %%
for j in range(5):
    plt.plot(time_series[:, j])
plt.show()

# %%
print(time_series.shape)
# Out:
# (1200, 5)

# %%
cov_series_hat = np.zeros((100, 5, 5))
log_series_hat = np.zeros((100, 15))
for t in range(100):
    sliding_window = time_series[(t * 10):(t * 10 + 100), :]
    cov_hat = np.cov(sliding_window, rowvar=False)
    cov_series_hat[t, :, :] = cov_hat
    log_hat = logm(cov_hat)[np.triu_indices(5)]
    log_series_hat[t, :] = log_hat

# %%
fig = plt.figure(figsize=(4, 3), dpi=500)
for j in range(15):
    plt.plot(log_series_hat[:, j])
plt.xlabel('Time')
plt.title('Noisy Log-Euclidean Data')
#fig.tight_layout()
#plt.savefig('sine_data.png')
plt.show()

# %%
Y = log_series_hat
print(Y.shape)
# Out:
# (100, 15)

# %%
from factorgp import FactorGP
from inference import run_gibbs

# %%
dims = [1, 100, 15, 2]
model = FactorGP(dims)
model.update_conditional_latent(Y)

# %%
results = run_gibbs(Y, model, 50, 50, 0.5, verbose=True)
# Out:
#   2%|▏         | 1/50 [00:10<08:42, 10.66s/it]
# Current MSE: 0.0485868595177
# Current length scale: [10.18494642 10.02858768]
#   4%|▍         | 2/50 [00:21<08:33, 10.70s/it]
# Current MSE: 0.0188726297837
# Current length scale: [10.41156946 10.42821308]
#   6%|▌         | 3/50 [00:31<08:16, 10.57s/it]
# Current MSE: 0.0141101254371
# Current length scale: [10.7837935  10.85572239]
#   8%|▊         | 4/50 [00:41<08:02, 10.48s/it]
# Current MSE: 0.0140634096839
# Current length scale: [10.8424115   9.83795632]
#  10%|█         | 5/50 [00:52<07:47, 10.40s/it]
# Current MSE: 0.0133831048075
# Current length scale: [10.65961686 10.68673342]
#  12%|█▏        | 6/50 [01:02<07:37, 10.39s/it]
# Current MSE: 0.0128505986295
# Current length scale: [10.21475927 11.28386351]
#  14%|█▍        | 7/50 [01:14<07:41, 10.72s/it]
# Current MSE: 0.0112827849776
# Current length scale: [10.57065786 11.25668448]
#  16%|█▌        | 8/50 [01:24<07:30, 10.72s/it]
# Current MSE: 0.0134504177676
# Current length scale: [10.92392082 11.21995141]
#  18%|█▊        | 9/50 [01:35<07:16, 10.66s/it]
# Current MSE: 0.0122157135595
# Current length scale: [12.00374103 11.04944415]
#  20%|██        | 10/50 [01:45<07:04, 10.61s/it]
# Current MSE: 0.0114787594223
# Current length scale: [12.41666508 10.92099437]
#  22%|██▏       | 11/50 [01:57<07:04, 10.90s/it]
# Current MSE: 0.0118885563678
# Current length scale: [12.5048793  11.42237422]
#  24%|██▍       | 12/50 [02:07<06:50, 10.79s/it]
# Current MSE: 0.0117108946479
# Current length scale: [13.35303024 11.74835627]
#  26%|██▌       | 13/50 [02:18<06:35, 10.69s/it]
# Current MSE: 0.011617978623
# Current length scale: [13.58547865 11.47043391]
#  28%|██▊       | 14/50 [02:28<06:24, 10.67s/it]
# Current MSE: 0.0113534382666
# Current length scale: [13.83341157 11.30550036]
#  30%|███       | 15/50 [02:39<06:06, 10.48s/it]
# Current MSE: 0.0116426645527
# Current length scale: [13.06655493 11.48059965]
#  32%|███▏      | 16/50 [02:49<05:51, 10.34s/it]
# Current MSE: 0.011614826733
# Current length scale: [13.3960707  11.53109274]
#  34%|███▍      | 17/50 [02:59<05:37, 10.23s/it]
# Current MSE: 0.0114024213829
# Current length scale: [13.39340961 11.7443472 ]
#  36%|███▌      | 18/50 [03:08<05:24, 10.15s/it]
# Current MSE: 0.0114484906905
# Current length scale: [12.82836911 11.48140225]
#  38%|███▊      | 19/50 [03:19<05:15, 10.19s/it]
# Current MSE: 0.0110825727171
# Current length scale: [13.47183121 11.70378222]
#  40%|████      | 20/50 [03:29<05:02, 10.08s/it]
# Current MSE: 0.0117067272779
# Current length scale: [12.65268901 10.98802129]
#  42%|████▏     | 21/50 [03:39<04:51, 10.05s/it]
# Current MSE: 0.0114888447149
# Current length scale: [12.82358679 11.32055862]
#  44%|████▍     | 22/50 [03:49<04:41, 10.06s/it]
# Current MSE: 0.0115638543446
# Current length scale: [13.53489595 11.83852647]
#  46%|████▌     | 23/50 [03:59<04:31, 10.05s/it]
# Current MSE: 0.0116623094561
# Current length scale: [13.94730536 13.11304846]
#  48%|████▊     | 24/50 [04:09<04:20, 10.03s/it]
# Current MSE: 0.0110546307046
# Current length scale: [14.29679304 12.77714514]
#  50%|█████     | 25/50 [04:19<04:10, 10.02s/it]
# Current MSE: 0.0108968450678
# Current length scale: [15.3604165  13.64279373]
#  52%|█████▏    | 26/50 [04:28<03:59,  9.97s/it]
# Current MSE: 0.0107169729005
# Current length scale: [14.81482608 15.382931  ]
#  54%|█████▍    | 27/50 [04:39<03:49, 10.00s/it]
# Current MSE: 0.0117852012823
# Current length scale: [15.12024917 14.10948497]
#  56%|█████▌    | 28/50 [04:48<03:38,  9.94s/it]
# Current MSE: 0.0114071712416
# Current length scale: [15.56797333 14.84992229]
#  58%|█████▊    | 29/50 [04:58<03:29,  9.96s/it]
# Current MSE: 0.0112994719226
# Current length scale: [16.30555101 13.87467506]
#  60%|██████    | 30/50 [05:08<03:19, 10.00s/it]
# Current MSE: 0.0114454023063
# Current length scale: [17.38400496 15.49174359]
#  62%|██████▏   | 31/50 [05:18<03:09,  9.97s/it]
# Current MSE: 0.0111985733728
# Current length scale: [16.14516526 16.51481227]
#  64%|██████▍   | 32/50 [05:28<02:59, 10.00s/it]
# Current MSE: 0.0108590248927
# Current length scale: [16.30987564 16.58347002]
#  66%|██████▌   | 33/50 [05:38<02:49,  9.95s/it]
# Current MSE: 0.0109744476932
# Current length scale: [16.00907799 17.32301349]
#  68%|██████▊   | 34/50 [05:48<02:39,  9.98s/it]
# Current MSE: 0.0109250096194
# Current length scale: [16.36833445 17.45710931]
#  70%|███████   | 35/50 [05:58<02:29,  9.96s/it]
# Current MSE: 0.0109057895284
# Current length scale: [16.43214207 16.87574915]
#  72%|███████▏  | 36/50 [06:08<02:19,  9.98s/it]
# Current MSE: 0.0114291725265
# Current length scale: [15.26263386 16.35052128]
#  74%|███████▍  | 37/50 [06:19<02:11, 10.09s/it]
# Current MSE: 0.0112844769596
# Current length scale: [16.23775229 16.1888342 ]
#  76%|███████▌  | 38/50 [06:30<02:05, 10.45s/it]
# Current MSE: 0.010930633946
# Current length scale: [17.16008957 15.61149238]
#  78%|███████▊  | 39/50 [06:41<01:58, 10.76s/it]
# Current MSE: 0.0110481848736
# Current length scale: [18.81680178 15.6580751 ]
#  80%|████████  | 40/50 [06:52<01:47, 10.74s/it]
# Current MSE: 0.0112509455087
# Current length scale: [19.90200236 14.32521324]
#  82%|████████▏ | 41/50 [07:03<01:36, 10.69s/it]
# Current MSE: 0.011375710004
# Current length scale: [19.03103758 15.12328455]
#  84%|████████▍ | 42/50 [07:14<01:26, 10.83s/it]
# Current MSE: 0.0112389460612
# Current length scale: [16.84628101 15.64056087]
#  86%|████████▌ | 43/50 [07:25<01:17, 11.08s/it]
# Current MSE: 0.0111756275246
# Current length scale: [16.68755184 14.43484802]
#  88%|████████▊ | 44/50 [07:37<01:06, 11.11s/it]
# Current MSE: 0.0113249958352
# Current length scale: [18.2055805  14.00981667]
#  90%|█████████ | 45/50 [07:51<00:59, 11.98s/it]
# Current MSE: 0.0116620520463
# Current length scale: [17.18187216 14.66348049]
#  92%|█████████▏| 46/50 [08:04<00:49, 12.26s/it]
# Current MSE: 0.0114106395565
# Current length scale: [15.88828767 14.20183947]
#  94%|█████████▍| 47/50 [08:14<00:34, 11.66s/it]
# Current MSE: 0.0113797376661
# Current length scale: [15.84141746 13.70581909]
#  96%|█████████▌| 48/50 [08:24<00:22, 11.27s/it]
# Current MSE: 0.0112437257589
# Current length scale: [17.45122361 13.17115232]
#  98%|█████████▊| 49/50 [08:34<00:10, 10.90s/it]
# Current MSE: 0.0115321700115
# Current length scale: [16.62887911 13.21095967]
# 100%|██████████| 50/50 [08:45<00:00, 10.81s/it]
# Current MSE: 0.0113424453747
# Current length scale: [17.88528596 12.50199828]

# %%
F_sample, loading_sample, variance_sample, theta_sample, traces_hist, mse_history = results

# %%
fig = plt.figure(figsize=(4, 3), dpi=150)
plt.plot(mse_history)
plt.title('Model MSE')
plt.xlabel('Iteration')
plt.show()

# %%
fig = plt.figure(figsize=(4, 3), dpi=500)
for i in range(10, 50):
    plt.plot(F_sample[i, :, 0], color=sophie_taeuber_arp[1], alpha=0.4)
    plt.plot(F_sample[i, :, 1], color=sophie_taeuber_arp[0], alpha=0.4)
plt.xlabel('Time')
plt.title('Latent Factor Posteriors')
fig.tight_layout()
plt.savefig('sine_latent.png')
plt.show()

# %%
fig = plt.figure(figsize=(4, 3), dpi=500)
t = np.arange(0, 1.2, 0.001)
y1 = np.sin(4 * np.pi * t)
y2 = np.sin(4 * np.pi * t + 1.0)
for k in range(3, 1007, 2):
    y1 = y1 + np.sin(4 * np.pi * k * t) / k
    y2 = y2 + np.sin((4 * np.pi * t + 1.0) * k) / k
plt.plot(t, y1, sophie_taeuber_arp[0])
plt.plot(t, y2, sophie_taeuber_arp[1])
plt.xlim(0, 1)
plt.xlabel('Time')
plt.title('True Latent Signal')
fig.tight_layout()
plt.savefig('square_signal.png')
plt.show()

# %%
F = np.zeros((1200, 2))
F[:, 0] = y1
F[:, 1] = y2

# %%
log_series = np.matmul(F, B)
print(log_series.shape)
# Out:
# (1200, 15)

# %%
for j in range(15):
    plt.plot(log_series[:1000, j])
plt.show()

# %%
cov_series = np.zeros((1200, 5, 5))
for i in range(1200):
    cov_series[i, :, :] = expm(create_symmetric_matrix(log_series[i, :]))

# %%
fig = plt.figure(figsize=(10, 4), dpi=150)
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cov_series[i * 100, :, :])
    plt.xticks([])
    plt.yticks([])
plt.colorbar()
plt.show()

# %%
time_series = np.zeros((1200, 5))
for i in range(1200):
    time_series[i, :] = np.random.multivariate_normal(np.zeros(5), cov_series[i, :, :], 1)

# %%
for j in range(5):
    plt.plot(time_series[:, j])
plt.show()

# %%
cov_series_hat = np.zeros((100, 5, 5))
log_series_hat = np.zeros((100, 15))
for t in range(100):
    sliding_window = time_series[(t * 10):(t * 10 + 50), :]
    cov_hat = np.cov(sliding_window, rowvar=False)
    cov_series_hat[t, :, :] = cov_hat
    log_hat = logm(cov_hat)[np.triu_indices(5)]
    log_series_hat[t, :] = log_hat

# %%
for j in range(15):
    plt.plot(log_series_hat[:, j])
plt.show()

# %%
Y = log_series_hat
print(Y.shape)
# Out:
# (100, 15)

# %%
dims = [1, 100, 15, 2]
model = FactorGP(dims)
model.update_conditional_latent(Y)

# %%
results = run_gibbs(Y, model, 50, 50, 0.5, verbose=True)
# Out:
#   2%|▏         | 1/50 [00:12<10:21, 12.69s/it]
# Current MSE: 0.153802800705
# Current length scale: [9.26516711 9.69929412]
#   4%|▍         | 2/50 [00:25<10:06, 12.64s/it]
# Current MSE: 0.0641167714685
# Current length scale: [8.93205456 8.54355739]
#   6%|▌         | 3/50 [00:36<09:40, 12.36s/it]
# Current MSE: 0.0545288343772
# Current length scale: [8.88507982 8.23826214]
#   8%|▊         | 4/50 [00:49<09:32, 12.45s/it]
# Current MSE: 0.0526128893475
# Current length scale: [8.80498872 8.23381733]
#  10%|█         | 5/50 [01:01<09:09, 12.21s/it]
# Current MSE: 0.0569866618969
# Current length scale: [8.4593476  7.23557395]
#  12%|█▏        | 6/50 [01:13<08:54, 12.15s/it]
# Current MSE: 0.0524434128009
# Current length scale: [8.32237005 7.22993296]
#  14%|█▍        | 7/50 [01:25<08:49, 12.31s/it]
# Current MSE: 0.0522880098207
# Current length scale: [8.03354192 7.15350873]
#  16%|█▌        | 8/50 [01:37<08:28, 12.10s/it]
# Current MSE: 0.0513057195773
# Current length scale: [7.72252683 7.47964514]
#  18%|█▊        | 9/50 [01:49<08:14, 12.06s/it]
# Current MSE: 0.0519595886053
# Current length scale: [7.63702251 7.6677798 ]
#  20%|██        | 10/50 [02:01<08:00, 12.02s/it]
# Current MSE: 0.0509401028624
# Current length scale: [7.48270455 7.50361319]
#  22%|██▏       | 11/50 [02:14<07:56, 12.21s/it]
# Current MSE: 0.050951125878
# Current length scale: [7.05398803 7.31650516]
#  24%|██▍       | 12/50 [02:26<07:50, 12.38s/it]
# Current MSE: 0.0520545729126
# Current length scale: [6.8611786  6.98108008]
#  26%|██▌       | 13/50 [02:43<08:26, 13.68s/it]
# Current MSE: 0.0502858622864
# Current length scale: [6.83329441 7.10231137]
#  28%|██▊       | 14/50 [02:55<07:51, 13.10s/it]
# Current MSE: 0.0504660702386
# Current length scale: [6.35794162 6.83036269]
#  30%|███       | 15/50 [03:07<07:28, 12.82s/it]
# Current MSE: 0.049365600608
# Current length scale: [6.37857065 6.63843771]
#  32%|███▏      | 16/50 [03:19<07:02, 12.43s/it]
# Current MSE: 0.0485577685893
# Current length scale: [6.30409766 6.7896674 ]
#  34%|███▍      | 17/50 [03:30<06:40, 12.14s/it]
# Current MSE: 0.0488047607959
# Current length scale: [6.24697979 6.38485623]
#  36%|███▌      | 18/50 [03:42<06:25, 12.05s/it]
# Current MSE: 0.0493652783933
# Current length scale: [5.98295743 6.47480723]
#  38%|███▊      | 19/50 [03:54<06:15, 12.13s/it]
# Current MSE: 0.0500728817905
# Current length scale: [5.60919445 6.35814266]
#  40%|████      | 20/50 [04:06<06:01, 12.04s/it]
# Current MSE: 0.0492232200758
# Current length scale: [5.48495585 6.14429393]
#  42%|████▏     | 21/50 [04:18<05:47, 12.00s/it]
# Current MSE: 0.04962270035
# Current length scale: [5.63189736 6.03099168]
#  44%|████▍     | 22/50 [04:30<05:36, 12.03s/it]
# Current MSE: 0.0500757498773
# Current length scale: [5.76575861 5.90036356]
#  46%|████▌     | 23/50 [04:41<05:19, 11.84s/it]
# Current MSE: 0.047706548568
# Current length scale: [5.92294823 6.02077375]
#  48%|████▊     | 24/50 [04:53<05:06, 11.78s/it]
# Current MSE: 0.0483100025759
# Current length scale: [5.84499041 5.67701867]
#  50%|█████     | 25/50 [05:05<04:57, 11.92s/it]
# Current MSE: 0.0490769856452
# Current length scale: [5.60349641 5.66352398]
#  52%|█████▏    | 26/50 [05:17<04:44, 11.86s/it]
# Current MSE: 0.0480926069753
# Current length scale: [5.64879356 5.8392485 ]
#  54%|█████▍    | 27/50 [05:28<04:29, 11.73s/it]
# Current MSE: 0.0489049571965
# Current length scale: [5.89685287 6.05732553]
#  56%|█████▌    | 28/50 [05:41<04:26, 12.12s/it]
# Current MSE: 0.0489380432225
# Current length scale: [5.71742423 6.14615646]
#  58%|█████▊    | 29/50 [05:53<04:12, 12.00s/it]
# Current MSE: 0.0485803896402
# Current length scale: [5.80030082 6.19763599]
#  60%|██████    | 30/50 [06:05<03:59, 11.95s/it]
# Current MSE: 0.0481170052604
# Current length scale: [5.75643238 6.33085047]
#  62%|██████▏   | 31/50 [06:16<03:43, 11.78s/it]
# Current MSE: 0.0491613544728
# Current length scale: [5.85017655 6.33421391]
#  64%|██████▍   | 32/50 [06:27<03:27, 11.53s/it]
# Current MSE: 0.048315527676
# Current length scale: [5.46186499 6.34831707]
#  66%|██████▌   | 33/50 [06:38<03:12, 11.30s/it]
# Current MSE: 0.0484613762544
# Current length scale: [5.40363507 6.38759725]
#  68%|██████▊   | 34/50 [06:49<02:58, 11.16s/it]
# Current MSE: 0.0493944705752
# Current length scale: [5.436288   6.14735157]
#  70%|███████   | 35/50 [07:00<02:46, 11.07s/it]
# Current MSE: 0.0500786278292
# Current length scale: [5.33842199 6.30741244]
#  72%|███████▏  | 36/50 [07:11<02:36, 11.19s/it]
# Current MSE: 0.0499024312214
# Current length scale: [5.65010285 6.1574637 ]
#  74%|███████▍  | 37/50 [07:22<02:24, 11.11s/it]
# Current MSE: 0.0487922844846
# Current length scale: [5.66945434 6.17344727]
#  76%|███████▌  | 38/50 [07:34<02:15, 11.27s/it]
# Current MSE: 0.0490229711233
# Current length scale: [5.75612392 5.98763516]
#  78%|███████▊  | 39/50 [07:45<02:04, 11.36s/it]
# Current MSE: 0.0469900194401
# Current length scale: [5.42252881 6.00338611]
#  80%|████████  | 40/50 [07:57<01:53, 11.32s/it]
# Current MSE: 0.0484860758751
# Current length scale: [5.24744478 5.76814568]
#  82%|████████▏ | 41/50 [08:08<01:42, 11.39s/it]
# Current MSE: 0.0490356274403
# Current length scale: [5.02986157 5.53769366]
#  84%|████████▍ | 42/50 [08:20<01:32, 11.59s/it]
# Current MSE: 0.0491306254148
# Current length scale: [5.11240919 5.62966735]
#  86%|████████▌ | 43/50 [08:32<01:22, 11.78s/it]
# Current MSE: 0.0484261428898
# Current length scale: [5.05410547 5.61521613]
#  88%|████████▊ | 44/50 [08:44<01:09, 11.64s/it]
# Current MSE: 0.0489048866272
# Current length scale: [5.09004457 5.34436647]
#  90%|█████████ | 45/50 [08:55<00:57, 11.48s/it]
# Current MSE: 0.0470020628215
# Current length scale: [4.96557993 5.38034544]
#  92%|█████████▏| 46/50 [09:06<00:45, 11.41s/it]
# Current MSE: 0.0472156039716
# Current length scale: [4.99229589 5.45658774]
#  94%|█████████▍| 47/50 [09:17<00:33, 11.25s/it]
# Current MSE: 0.0487292496446
# Current length scale: [4.90742689 5.31035611]
#  96%|█████████▌| 48/50 [09:28<00:22, 11.24s/it]
# Current MSE: 0.0489149417805
# Current length scale: [4.88676853 5.30239942]
#  98%|█████████▊| 49/50 [09:40<00:11, 11.40s/it]
# Current MSE: 0.0493911238002
# Current length scale: [4.87487716 5.31396527]
# 100%|██████████| 50/50 [09:51<00:00, 11.24s/it]
# Current MSE: 0.0485434445949
# Current length scale: [4.79707897 5.17538026]

# %%
F_sample, loading_sample, variance_sample, theta_sample, traces_hist, mse_history = results

# %%
fig = plt.figure(figsize=(4, 3), dpi=150)
plt.plot(mse_history)
plt.title('Model MSE')
plt.xlabel('Iteration')
plt.show()

# %%
fig = plt.figure(figsize=(4, 3), dpi=500)
for i in range(10, 50):
    plt.plot(-F_sample[i, :, 0], color=sophie_taeuber_arp[0], alpha=0.4)
    plt.plot(F_sample[i, :, 1], color=sophie_taeuber_arp[1], alpha=0.4)
plt.xlabel('Time')
plt.title('Latent Factor Posteriors')
fig.tight_layout()
plt.savefig('square_latent.png')
plt.show()
